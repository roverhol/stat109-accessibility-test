# %% [markdown]
# # Project 2 — Milestone notebook
#
# **Phase A** of [Project 2](project-2) with a more detailed description here: [project-2-milestone](project-2-milestone).
#
# Complete steps **1–4** before you collect data or compute a confidence interval.

# %% [markdown]
# ## Step 1 — Choose a finite population you can list
#
# Think of a **population you could list**, **randomly sample from the list**, and visit (or inspect) each sampled item to collect **one variable** — either a **number** or a **binary outcome**.
#
# It is hard to randomly sample **people** without university research approval and without a complete contact list for the population. For these reasons, I recommend a population of **non-human objects**. For example:
#
# - Number all parking spaces in a lot (e.g. from a Google Maps image), randomly select 10 spaces, and record one variable at each space (occupied or not? truck or not? white or not? model year?).
# - Sample from a numbered list of items on a website, as in the [sample project](project-2-example-ca-high-schools.qmd).
#
# **My population** *(name + how you will list every object from 1 to N):*
#
# ```
# [ your answer ]
# ```
#
# **Population size:** $N =$ ___

# %% [markdown]
# ## Step 2 — Choose the parameter and variable
#
# Once you have a population, decide what **mean** or **proportion** you want to estimate. Identify the **variable** you will collect for each sampled object.
#
# Your choices here commit you to a **mean** CI (`t.test` + FPC when needed) or a **proportion** CI (`binom.test` / `prop.test` + FPC when needed) in Phase B.
#
# **My variable** *(what you will record at each sampled object):*
#
# ```
# [ your answer ]
# ```
#
# Variable type: ☐ binary categorical ☐ numerical (circle one)
#
# I will estimate a: ☐ proportion ☐ mean (circle one)

# %% [markdown]
# ## Step 3 — Choose a sample size
#
# Larger samples give **more precision**, but collecting data takes time. For this project, collect data from **10 objects** or the **largest number** you can feasibly visit in **1–2 hours** — whichever you choose as your sample size.
#
# **Planned sample size:** $n =$ ___
#
# **Brief note on feasibility** *(why this n is realistic in 1–2 hours):*
#
# ```
# [ your answer ]
# ```

# %% [markdown]
# ## Step 4 — Draw a simple random sample
#
# Use a **random number generator** to select $n$ **distinct** items from $1$ to $N$. We have used this one in class:
#
# [Rossman Chance random number generator](https://www.rossmanchance.com/applets/2021/randomnumbers/GenRandom01.htm)
#
# Optional in R (after you fix $N$ and $n$): `sample(1:N, n)` — do not replace IDs if you already listed them from the applet.
#
# **The $n$ items I need to visit** *(list distinct IDs from 1 to N):*
#
# ```
# [ your answer ]
# ```

# %% [markdown]
# ## Submit in Canvas
#
# 1. **Step 1** — Population description and $N$
# 2. **Step 2** — Variable type; mean vs proportion
# 3. **Step 3** — Planned sample size $n$
# 4. **Step 4** — List of $n$ distinct SRS IDs
#
# Do **not** include collected data, graphs, or a confidence interval yet — that is Phase B on the [Project 2](project-2) page.
