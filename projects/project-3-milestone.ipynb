# %% [markdown]
# # Project 3 — Milestone notebook (Phase A)
#
# Phase A of [Project 3](project-3). Detailed instructions: [project-3-milestone](project-3-milestone).
#
# Complete steps A1–A4 before univariate/bivariate plots or the one-page summary (Phase B).
#
# In Colab: Runtime → Change runtime type → R.

# %% [markdown]
# ## Step A1 — Choose a dataset
#
# 1. Open a year folder on [TidyTuesday](https://github.com/rfordatascience/tidytuesday/tree/main/data) (for example [2020](https://github.com/rfordatascience/tidytuesday/tree/main/data/2020)).
# 2. Click one week folder that interests you.
# 3. Open `readme.md` — read the description, source, and Data Dictionary.
# 4. Paste the week’s GitHub folder link and a one-sentence description below.
#
# TidyTuesday week link:
#
# ```
# [ paste https://github.com/rfordatascience/tidytuesday/tree/main/data/YYYY/YYYY-MM-DD ]
# ```
#
# One-sentence description of the dataset:
#
# ```
# [ your answer ]
# ```

# %% [markdown]
# ## Step A2 — Load the data in Colab
#
# From the readme section “Get the data here”, copy the URL inside `read_csv('...')` under “Or read in the data manually”. Paste it in the code cell below.

# %%
library(tidyverse)

# Replace URL with yours from the TidyTuesday readme
my_data <- read_csv(
  "PASTE_RAW_GITHUB_URL_HERE"
)

# %% [markdown]
# ## Step A3 — Confirm the file loaded
#
# Run `glimpse()` to see column names, types, and a preview. Run `head()` if helpful.

# %%
glimpse(my_data)
head(my_data, 10)

# Optional: how many rows and columns?
nrow(my_data)
ncol(my_data)

# %% [markdown]
# ## Step A4 — Choose four variables
#
# From all columns in the dataset, pick four you will analyze in Project 3. Use the readme Data Dictionary for descriptions. Classify each as categorical or numerical.
#
# | Variable name (column) | Description (from readme) | Type (categorical or numerical) |
# |------------------------|---------------------------|----------------------------------|
# | | | |
# | | | |
# | | | |
# | | | |
#
# Check: at least one categorical and at least one numerical recommended; at least 10 rows in the dataset.

# %% [markdown]
# ## Submit (Optional)
#
# Upload this notebook to the Project 3 — Milestone assignment in Canvas.
